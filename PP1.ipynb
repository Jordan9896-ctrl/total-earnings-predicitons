# %% [markdown]
# # **Project 1 - Part 1**
# Jordan Cofield

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Exploratory Visuals

# %% [markdown]
# ## Explanatory Visuals
